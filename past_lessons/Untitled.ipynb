# %%
from matplotlib import pyplot as plt
import numpy as np

# Generate 100 random data points along 3 dimensions
x, y, scale = np.random.randn(3, 100)
fig, ax = plt.subplots()

# Map each onto a scatterplot we'll create with Matplotlib
ax.scatter(x=x, y=y, c=scale, s=np.abs(scale)*500)
ax.set(title="Some random data, created with JupyterLab!")
plt.show()

# %%
import sys
print(sys.path)
help("modules")
days_of_the_week = 7
def say_hello(recipient):
    print("Hello, world! Hello {} ".format(recipient))
    return recipient
# Out:
# ['C:\\Users\\b1041827\\repos\\PLUS_softwaredev_2022', 'C:\\ProgramData\\Anaconda3\\python38.zip', 'C:\\ProgramData\\Anaconda3\\DLLs', 'C:\\ProgramData\\Anaconda3\\lib', 'C:\\ProgramData\\Anaconda3', '', 'C:\\ProgramData\\Anaconda3\\lib\\site-packages', 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\win32', 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\win32\\lib', 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\Pythonwin', 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\IPython\\extensions', 'C:\\Users\\b1041827\\.ipython']
#
# Please wait a moment while I gather a list of all available modules...
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\kernel\__init__.py:12: ShimWarning: The `IPython.kernel` package has been deprecated since IPython 4.0.You should import from ipykernel or jupyter_client instead.
#   warn("The `IPython.kernel` package has been deprecated since IPython 4.0."
# C:\ProgramData\Anaconda3\lib\site-packages\nltk\twitter\__init__.py:21: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\setuptools\distutils_patch.py:25: UserWarning: Distutils was imported before Setuptools. This usage is discouraged and may exhibit undesirable behaviors or errors. Please use Setuptools' objects directly or at least import Setuptools first.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\skimage\viewer\utils\__init__.py:1: UserWarning: Recommended matplotlib backend is `Agg` for full skimage.viewer functionality.
#   from .core import *
# C:\ProgramData\Anaconda3\lib\site-packages\qtawesome\iconic_font.py:312: UserWarning: You need to have a running QApplication to use QtAwesome!
#   warnings.warn("You need to have a running "
# C:\ProgramData\Anaconda3\lib\pkgutil.py:107: VisibleDeprecationWarning: zmq.eventloop.minitornado is deprecated in pyzmq 14.0 and will be removed.
#     Install tornado itself to use zmq with the tornado IOLoop.
#
#   yield from walk_packages(path, info.name+'.', onerror)
# Cython              brain_responses     markupsafe          socket
# IPython             brain_scipy_signal  marshal             socketserver
# OpenSSL             brain_six           math                socks
# PIL                 brain_ssl           matplotlib          sockshandler
# PyQt5               brain_subprocess    mccabe              sortedcollections
# __future__          brain_threading     menuinst            sortedcontainers
# _abc                brain_typing        mimetypes           soupsieve
# _ast                brain_uuid          mistune             sphinx
# _asyncio            brotli              mkl                 sphinxcontrib
# _bisect             bs4                 mkl_fft             spyder
# _blake2             builtins            mkl_random          spyder_kernels
# _bootlocale         bz2                 mmap                sqlalchemy
# _bz2                cProfile            mmapfile            sqlite3
# _cffi_backend       calendar            mmsystem            sre_compile
# _codecs             certifi             mock                sre_constants
# _codecs_cn          cffi                modulefinder        sre_parse
# _codecs_hk          cgi                 more_itertools      ssl
# _codecs_iso2022     cgitb               mpmath              sspi
# _codecs_jp          chardet             msgpack             sspicon
# _codecs_kr          chunk               msilib              stat
# _codecs_tw          click               msvcrt              statistics
# _collections        cloudpickle         multipledispatch    statsmodels
# _collections_abc    clyent              multiprocessing     storemagic
# _compat_pickle      cmath               nacl                string
# _compression        cmd                 navigator_updater   stringprep
# _contextvars        code                nbconvert           struct
# _csv                codecs              nbformat            subprocess
# _ctypes             codeop              netbios             sunau
# _ctypes_test        collections         netrc               symbol
# _datetime           colorama            networkx            sympy
# _decimal            colorsys            nltk                sympyprinting
# _dummy_thread       commctrl            nntplib             symtable
# _elementtree        compileall          nose                sys
# _functools          comtypes            notebook            sysconfig
# _hashlib            concurrent          nt                  tables
# _heapq              conda               ntpath              tabnanny
# _imp                conda_build         ntsecuritycon       tarfile
# _io                 conda_env           nturl2path          tblib
# _json               conda_package_handling numba               telnetlib
# _locale             conda_verify        numbers             tempfile
# _lsprof             configparser        numexpr             terminado
# _lzma               contextlib          numpy               test
# _markupbase         contextlib2         numpydoc            test_pycosat
# _md5                contextvars         odbc                testpath
# _msi                copy                olefile             tests
# _multibytecodec     copyreg             opcode              textwrap
# _multiprocessing    crypt               openpyxl            this
# _nsis               cryptography        operator            threading
# _opcode             csv                 optparse            threadpoolctl
# _operator           ctypes              os                  time
# _osx_support        curl                packaging           timeit
# _overlapped         curses              pandas              timer
# _pickle             cwp                 pandocfilters       tkinter
# _py_abc             cycler              paramiko            tlz
# _pydecimal          cython              parser              token
# _pyio               cythonmagic         parso               tokenize
# _pyrsistent_version cytoolz             partd               toml
# _pytest             dask                past                toolz
# _queue              dataclasses         path                tornado
# _random             datetime            pathlib             tqdm
# _sha1               dateutil            pathlib2            trace
# _sha256             dbi                 pathtools           traceback
# _sha3               dbm                 patsy               tracemalloc
# _sha512             dde                 pdb                 traitlets
# _signal             decimal             pep8                tty
# _sitebuiltins       decorator           perfmon             turtle
# _socket             defusedxml          pexpect             turtledemo
# _sqlite3            diff_match_patch    pickle              types
# _sre                difflib             pickleshare         typing
# _ssl                dis                 pickletools         typing_extensions
# _stat               distributed         pip                 ujson
# _statistics         distutils           pipes               unicodecsv
# _string             doctest             pkg_resources       unicodedata
# _strptime           docutils            pkginfo             unittest
# _struct             dummy_threading     pkgutil             untitled
# _symtable           easy_install        platform            urllib
# _system_path        email               plistlib            urllib3
# _testbuffer         encodings           pluggy              uu
# _testcapi           ensurepip           ply                 uuid
# _testconsole        entrypoints         poplib              venv
# _testimportmultiple enum                posixpath           warnings
# _testinternalcapi   errno               pprint              watchdog
# _testmultiphase     et_xmlfile          profile             wave
# _thread             fastcache           prometheus_client   wcwidth
# _threading_local    faulthandler        prompt_toolkit      weakref
# _tkinter            filecmp             pstats              webbrowser
# _tracemalloc        fileinput           psutil              webencodings
# _warnings           filelock            pty                 werkzeug
# _weakref            flake8              pvectorc            wheel
# _weakrefset         flask               py                  widgetsnbextension
# _win32sysloader     fnmatch             py_compile          win2kras
# _winapi             formatter           pyclbr              win32api
# _winxptheme         fractions           pycodestyle         win32clipboard
# _xxsubinterpreters  fsspec              pycosat             win32com
# _yaml               ftplib              pycparser           win32con
# a_python            functools           pycurl              win32console
# abc                 future              pydoc               win32cred
# adodbapi            gc                  pydoc_data          win32crypt
# afxres              genericpath         pydocstyle          win32cryptcon
# aifc                getopt              pyexpat             win32ctypes
# alabaster           getpass             pyflakes            win32event
# anaconda_navigator  gettext             pygments            win32evtlog
# anaconda_project    gevent              pylab               win32evtlogutil
# antigravity         glob                pylint              win32file
# argh                glob2               pyls                win32gui
# argparse            gmpy2               pyls_jsonrpc        win32gui_struct
# array               greenlet            pyodbc              win32help
# asn1crypto          gzip                pyparsing           win32inet
# ast                 h5py                pyreadline          win32inetcon
# astroid             hashlib             pyrsistent          win32job
# astropy             heapdict            pytest              win32lz
# asynchat            heapq               pythoncom           win32net
# asyncio             hmac                pytz                win32netcon
# asyncore            html                pywin               win32pdh
# atexit              html5lib            pywin32_bootstrap   win32pdhquery
# atomicwrites        http                pywin32_testutil    win32pdhutil
# attr                idlelib             pywintypes          win32pipe
# audioop             idna                pywt                win32print
# autopep8            imageio             pyximport           win32process
# autoreload          imagesize           qdarkstyle          win32profile
# babel               imaplib             qtawesome           win32ras
# backcall            imghdr              qtconsole           win32rcparser
# backports           imp                 qtpy                win32security
# base64              importlib           queue               win32service
# bcrypt              importlib_metadata  quopri              win32serviceutil
# bdb                 inspect             random              win32timezone
# binascii            intervaltree        rasutil             win32trace
# binhex              io                  re                  win32traceutil
# binstar_client      ipaddress           readline            win32transaction
# bisect              ipykernel           regcheck            win32ts
# bitarray            ipykernel_launcher  regex               win32ui
# bkcharts            ipython_genutils    regutil             win32uiole
# bleach              ipywidgets          reprlib             win32verstamp
# bokeh               isapi               requests            win32wnet
# boto                isort               rlcompleter         win_inet_pton
# bottleneck          isympy              rmagic              win_unicode_console
# brain_argparse      itertools           rope                wincertstore
# brain_attrs         itsdangerous        rtree               winerror
# brain_boto3         jdcal               ruamel_yaml         winioctlcon
# brain_builtin_inference jedi                run                 winnt
# brain_collections   jinja2              runpy               winperf
# brain_crypt         joblib              sched               winpty
# brain_curses        json                scipy               winreg
# brain_dataclasses   json5               scripts             winsound
# brain_dateutil      jsonschema          seaborn             winxpgui
# brain_fstrings      jupyter             secrets             winxptheme
# brain_functools     jupyter_client      select              wrapt
# brain_gi            jupyter_console     selectors           wsgiref
# brain_hashlib       jupyter_core        send2trash          xdrlib
# brain_http          jupyterlab          servicemanager      xlrd
# brain_io            jupyterlab_server   setuptools          xlsxwriter
# brain_mechanize     keyring             shelve              xlwings
# brain_multiprocessing keyword             shlex               xlwt
# brain_namedtuple_enum kiwisolver          shutil              xml
# brain_nose          lazy_object_proxy   signal              xmlrpc
# brain_numpy_core_fromnumeric lib2to3             simplegeneric       xmltodict
# brain_numpy_core_function_base libarchive          singledispatch      xxsubtype
# brain_numpy_core_multiarray libfuturize         singledispatch_helpers yaml
# brain_numpy_core_numeric libpasteurize       sip                 yapf
# brain_numpy_core_numerictypes lief                sipconfig           yapftests
# brain_numpy_core_umath linecache           sipdistutils        zict
# brain_numpy_ndarray llvmlite            site                zipapp
# brain_numpy_random_mtrand locale              six                 zipfile
# brain_numpy_utils   locket              skimage             zipimport
# brain_pkg_resources logging             sklearn             zipp
# brain_pytest        lxml                smtpd               zlib
# brain_qt            lzma                smtplib             zmq
# brain_random        mailbox             sndhdr              zope
# brain_re            mailcap             snowballstemmer
#
# Enter any module name to get more help.  Or, type "modules spam" to search
# for modules whose name or summary contain the string "spam".

# %%
say_hello("test")
# Out:
# Hello, world! Hello test
# 'test'

# %%
import untitled
# Out:
# ['C:\\ProgramData\\Anaconda3\\lib\\site-packages\\spyder\\plugins\\help\\utils', 'C:\\Users\\b1041827\\repos', 'C:\\Users\\b1041827\\repos\\PLUS_softwaredev_2022', 'C:\\ProgramData\\Anaconda3\\python38.zip', 'C:\\ProgramData\\Anaconda3\\DLLs', 'C:\\ProgramData\\Anaconda3\\lib', 'C:\\ProgramData\\Anaconda3', '', 'C:\\ProgramData\\Anaconda3\\lib\\site-packages', 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\win32', 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\win32\\lib', 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\Pythonwin', 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\IPython\\extensions', 'C:\\Users\\b1041827\\.ipython', 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\astroid\\brain']
#
# Please wait a moment while I gather a list of all available modules...
#
# Cython              brain_scipy_signal  marshal             socks
# IPython             brain_six           math                sockshandler
# OpenSSL             brain_ssl           matplotlib          sortedcollections
# PIL                 brain_subprocess    mccabe              sortedcontainers
# PyQt5               brain_threading     menuinst            soupsieve
# __future__          brain_typing        mimetypes           sphinx
# _abc                brain_uuid          mistune             sphinxcontrib
# _ast                brotli              mkl                 sphinxify
# _asyncio            bs4                 mkl_fft             sphinxthread
# _bisect             builtins            mkl_random          spyder
# _blake2             bz2                 mmap                spyder_kernels
# _bootlocale         cProfile            mmapfile            sqlalchemy
# _bz2                calendar            mmsystem            sqlite3
# _cffi_backend       certifi             mock                sre_compile
# _codecs             cffi                modulefinder        sre_constants
# _codecs_cn          cgi                 more_itertools      sre_parse
# _codecs_hk          cgitb               mpmath              ssl
# _codecs_iso2022     chardet             msgpack             sspi
# _codecs_jp          chunk               msilib              sspicon
# _codecs_kr          click               msvcrt              stat
# _codecs_tw          cloudpickle         multipledispatch    statistics
# _collections        clyent              multiprocessing     statsmodels
# _collections_abc    cmath               nacl                storemagic
# _compat_pickle      cmd                 navigator_updater   string
# _compression        code                nbconvert           stringprep
# _contextvars        codecs              nbformat            struct
# _csv                codeop              netbios             subprocess
# _ctypes             collections         netrc               sunau
# _ctypes_test        colorama            networkx            symbol
# _datetime           colorsys            nltk                sympy
# _decimal            commctrl            nntplib             sympyprinting
# _dummy_thread       compileall          nose                symtable
# _elementtree        comtypes            notebook            sys
# _functools          concurrent          nt                  sysconfig
# _hashlib            conda               ntpath              tables
# _heapq              conda_build         ntsecuritycon       tabnanny
# _imp                conda_env           nturl2path          tarfile
# _io                 conda_package_handling numba               tblib
# _json               conda_verify        numbers             telnetlib
# _locale             conf                numexpr             tempfile
# _lsprof             configparser        numpy               terminado
# _lzma               contextlib          numpydoc            test
# _markupbase         contextlib2         odbc                test_pycosat
# _md5                contextvars         olefile             testpath
# _msi                copy                opcode              tests
# _multibytecodec     copyreg             openpyxl            textwrap
# _multiprocessing    crypt               operator            this
# _nsis               cryptography        optparse            threading
# _opcode             csv                 os                  threadpoolctl
# _operator           ctypes              packaging           time
# _osx_support        curl                pandas              timeit
# _overlapped         curses              pandocfilters       timer
# _pickle             cwp                 paramiko            tkinter
# _py_abc             cycler              parser              tlz
# _pydecimal          cython              parso               token
# _pyio               cythonmagic         partd               tokenize
# _pyrsistent_version cytoolz             past                toml
# _pytest             dask                path                toolz
# _queue              dataclasses         pathlib             tornado
# _random             datetime            pathlib2            tqdm
# _sha1               dateutil            pathtools           trace
# _sha256             dbi                 patsy               traceback
# _sha3               dbm                 pdb                 tracemalloc
# _sha512             dde                 pep8                traitlets
# _signal             decimal             perfmon             tty
# _sitebuiltins       decorator           pexpect             turtle
# _socket             defusedxml          pickle              turtledemo
# _sqlite3            diff_match_patch    pickleshare         types
# _sre                difflib             pickletools         typing
# _ssl                dis                 pip                 typing_extensions
# _stat               distributed         pipes               ujson
# _statistics         distutils           pkg_resources       unicodecsv
# _string             doctest             pkginfo             unicodedata
# _strptime           docutils            pkgutil             unittest
# _struct             dummy_threading     platform            untitled
# _symtable           easy_install        plistlib            urllib
# _system_path        email               pluggy              urllib3
# _testbuffer         encodings           ply                 uu
# _testcapi           ensurepip           poplib              uuid
# _testconsole        entrypoints         posixpath           venv
# _testimportmultiple enum                pprint              warnings
# _testinternalcapi   errno               profile             watchdog
# _testmultiphase     et_xmlfile          prometheus_client   wave
# _thread             fastcache           prompt_toolkit      wcwidth
# _threading_local    faulthandler        pstats              weakref
# _tkinter            filecmp             psutil              webbrowser
# _tracemalloc        fileinput           pty                 webencodings
# _warnings           filelock            pvectorc            werkzeug
# _weakref            flake8              py                  wheel
# _weakrefset         flask               py_compile          widgetsnbextension
# _win32sysloader     fnmatch             pyclbr              win2kras
# _winapi             formatter           pycodestyle         win32api
# _winxptheme         fractions           pycosat             win32clipboard
# _xxsubinterpreters  fsspec              pycparser           win32com
# _yaml               ftplib              pycurl              win32con
# a_python            functools           pydoc               win32console
# abc                 future              pydoc_data          win32cred
# adodbapi            gc                  pydocstyle          win32crypt
# afxres              genericpath         pyexpat             win32cryptcon
# aifc                getopt              pyflakes            win32ctypes
# alabaster           getpass             pygments            win32event
# anaconda_navigator  gettext             pylab               win32evtlog
# anaconda_project    gevent              pylint              win32evtlogutil
# antigravity         glob                pyls                win32file
# argh                glob2               pyls_jsonrpc        win32gui
# argparse            gmpy2               pyodbc              win32gui_struct
# array               greenlet            pyparsing           win32help
# asn1crypto          gzip                pyreadline          win32inet
# ast                 h5py                pyrsistent          win32inetcon
# astroid             hashlib             pytest              win32job
# astropy             heapdict            pythoncom           win32lz
# asynchat            heapq               pytz                win32net
# asyncio             hmac                pywin               win32netcon
# asyncore            html                pywin32_bootstrap   win32pdh
# atexit              html5lib            pywin32_testutil    win32pdhquery
# atomicwrites        http                pywintypes          win32pdhutil
# attr                idlelib             pywt                win32pipe
# audioop             idna                pyximport           win32print
# autopep8            imageio             qdarkstyle          win32process
# autoreload          imagesize           qtawesome           win32profile
# babel               imaplib             qtconsole           win32ras
# backcall            imghdr              qtpy                win32rcparser
# backports           imp                 queue               win32security
# base64              importlib           quopri              win32service
# bcrypt              importlib_metadata  random              win32serviceutil
# bdb                 inspect             rasutil             win32timezone
# binascii            intervaltree        re                  win32trace
# binhex              io                  readline            win32traceutil
# binstar_client      ipaddress           regcheck            win32transaction
# bisect              ipykernel           regex               win32ts
# bitarray            ipykernel_launcher  regutil             win32ui
# bkcharts            ipython_genutils    reprlib             win32uiole
# bleach              ipywidgets          requests            win32verstamp
# bokeh               isapi               rlcompleter         win32wnet
# boto                isort               rmagic              win_inet_pton
# bottleneck          isympy              rope                win_unicode_console
# brain_argparse      itertools           rtree               wincertstore
# brain_attrs         itsdangerous        ruamel_yaml         winerror
# brain_boto3         jdcal               run                 winioctlcon
# brain_builtin_inference jedi                runpy               winnt
# brain_collections   jinja2              sched               winperf
# brain_crypt         joblib              scipy               winpty
# brain_curses        json                scripts             winreg
# brain_dataclasses   json5               seaborn             winsound
# brain_dateutil      jsonschema          secrets             winxpgui
# brain_fstrings      jupyter             select              winxptheme
# brain_functools     jupyter_client      selectors           wrapt
# brain_gi            jupyter_console     send2trash          wsgiref
# brain_hashlib       jupyter_core        servicemanager      xdrlib
# brain_http          jupyterlab          setuptools          xlrd
# brain_io            jupyterlab_server   shelve              xlsxwriter
# brain_mechanize     keyring             shlex               xlwings
# brain_multiprocessing keyword             shutil              xlwt
# brain_namedtuple_enum kiwisolver          signal              xml
# brain_nose          lazy_object_proxy   simplegeneric       xmlrpc
# brain_numpy_core_fromnumeric lib2to3             singledispatch      xmltodict
# brain_numpy_core_function_base libarchive          singledispatch_helpers xxsubtype
# brain_numpy_core_multiarray libfuturize         sip                 yaml
# brain_numpy_core_numeric libpasteurize       sipconfig           yapf
# brain_numpy_core_numerictypes lief                sipdistutils        yapftests
# brain_numpy_core_umath linecache           site                zict
# brain_numpy_ndarray llvmlite            six                 zipapp
# brain_numpy_random_mtrand locale              skimage             zipfile
# brain_numpy_utils   locket              sklearn             zipimport
# brain_pkg_resources logging             smtpd               zipp
# brain_pytest        lxml                smtplib             zlib
# brain_qt            lzma                sndhdr              zmq
# brain_random        mailbox             snowballstemmer     zope
# brain_re            mailcap             socket
# brain_responses     markupsafe          socketserver
#
# Enter any module name to get more help.  Or, type "modules spam" to search
# for modules whose name or summary contain the string "spam".

# %%
# %%timeit
L = []
for n in range(1000):
    L.append(n ** 2)
# Out:
# 270 µs ± 8.03 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %who
# Out:
# days_of_the_week	 os	 say_hello	 sys	 untitled
